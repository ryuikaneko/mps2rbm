# %%
# get codes from github
# !git clone https://github.com/ryuikaneko/mps2rbm
# Out:
# Cloning into 'mps2rbm'...
# remote: Enumerating objects: 1601, done.
# remote: Counting objects: 100% (1601/1601), done.
# remote: Compressing objects: 100% (1060/1060), done.
# remote: Total 1601 (delta 553), reused 1575 (delta 535), pack-reused 0 (from 0)
# Receiving objects: 100% (1601/1601), 10.31 MiB | 9.82 MiB/s, done.
# Resolving deltas: 100% (553/553), done.

# %%
# copy minimum codes
# %cp -r /content/mps2rbm/codes_minimum/L8/tenpy_toycodes /content/
# %cp /content/mps2rbm/codes_minimum/L8/main_1_cpd.py /content/
# %cp /content/mps2rbm/codes_minimum/L8/main_2_rbm.py /content/
# %ls
# Out:
# main_1_cpd.py  main_2_rbm.py  mps2rbm/  sample_data/  tenpy_toycodes/

# %%
# CP decomposition of MPS
# run 100 iterations for L=8
# !python main_1_cpd.py
# Out:
# L 8
# g 1.0
# MPS bond dim D 4
# CPD rank 4
#
# finite DMRG, transverse field Ising
# L=8, g=1.00
# sweep  1: E = -9.8352347568345
# sweep  2: E = -9.8379511513073
# sweep  3: E = -9.8379510951088
# sweep  4: E = -9.8379510951063
# sweep  5: E = -9.8379510951063
# sweep  6: E = -9.8379510951063
# sweep  7: E = -9.8379510951063
# sweep  8: E = -9.8379510951063
# sweep  9: E = -9.8379510951063
# sweep 10: E = -9.8379510951063
# final bond dimensions:  [2, 4, 4, 4, 4, 4, 2]
# magnetization in X = 5.98339
# magnetization in Z = 0.00000
# Exact diagonalization: E = -9.8379514474594
# relative error:  3.581569762150928e-08
# DMRG Energy -9.837951095106325
#
# Gs.shape (2, 2) (2, 2, 4) (4, 2, 4) (4, 2, 4) (4, 2, 4) (4, 2, 4) (4, 2, 2) (2, 2)
#
# Analytical Energy -9.837951447459421
#
# CPD to MPS
# Iteration 1, error = 4.42e-01
# Iteration 2, error = 1.38e-01
# Iteration 3, error = 8.12e-02
# Iteration 4, error = 7.35e-02
# Iteration 5, error = 6.92e-02
# Iteration 6, error = 6.59e-02
# ...

# %%
# VMC of CP decomposed MPS
# run 200 iterations for L=8
# !python main_2_rbm.py
# Out:
# L 8
# g 1.0
# MPS bond dim D 4
# CPD rank 4
#
# initial RBM parameters
# e_exact(periodic) -10.251661790966025
# e_dmrg(open) -9.837951095106325
# b0s (4, 8)
# W0s (4, 8)
#
# run RBM VMC opt
# 0 -9.737557332345986 0.0
# 1 -9.745679223723998 0.0
# 2 -9.800875209601875 0.0
# 3 -9.774518996702959 0.0
# 4 -9.818288693939653 0.0
# 5 -9.85794772368106 0.0
# 6 -9.827447107616477 0.0
# 7 -9.839554185815636 0.0
# 8 -9.86691621283258 0.0
# 9 -9.854671535389318 0.0
# 10 -9.85863160910997 0.0
# 11 -9.886127160913217 0.0
# 12 -9.89405325935517 0.0
# 13 -9.881973320449049 0.0
# 14 -9.887715798839317 0.0
# 15 -9.91718329402301 0.0
# 16 -9.910454528856071 0.0
# 17 -9.938958554587494 0.0
# 18 -9.946231481743519 0.0
# 19 -9.962065490144935 0.0
# 20 -9.939234747350044 0.0
# 21 -9.932530204340816 0.0
# 22 -9.973773233741724 0.0
# 23 -9.964927651152628 0.0
# 24 -9.973321028944136 0.0
# 25 -9.966517880936685 0.0
# 26 -9.99242948569702 0.0
# 27 -9.981143599807302 0.0
# 28 -10.000850772864851 0.0
# ...

# %%
# check output file
# !cat dat_vmc_enes_ave_err_L8_g1.0000000000_D4_rank4_seed12345
# Out:
# # L g D rank seed exact(priodic) dmrg(open) vmc(periodic) vmc_err (vmc-exact)/exact vmc_err/exact
# 8.000000000000000000e+00 1.000000000000000000e+00 4.000000000000000000e+00 4.000000000000000000e+00 1.234500000000000000e+04 -1.025166179096602548e+01 -9.837951095106324928e+00 -1.011414762508627163e+01 6.867380899647533088e-04 1.341384145163022727e-02 6.698797755598228938e-05
